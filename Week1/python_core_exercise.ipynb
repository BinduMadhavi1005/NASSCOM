# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------

# %%
# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):
    timestamp = (start_time + datetime.timedelta(minutes=i)).strftime('%Y-%m-%d %H:%M:%S')
    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    raw_sensor_data.append((timestamp, device_id, device_type, location, value))
print(raw_sensor_data)
# Out:
# --- Task 1: Data Generation and Basic Structures ---
# [('2026-07-19 13:47:49', 'DEV001', 'Light_Sensor', 'Lab1', 415.1), ('2026-07-19 13:48:49', 'DEV002', 'Light_Sensor', 'Lab1', 629.24), ('2026-07-19 13:49:49', 'DEV003', 'Pressure_Sensor', 'OfficeA', 1026.65), ('2026-07-19 13:50:49', 'DEV004', 'Pressure_Sensor', 'Lab1', 1008.92), ('2026-07-19 13:51:49', 'DEV005', 'Temperature_Sensor', 'OfficeB', 23.82), ('2026-07-19 13:52:49', 'DEV006', 'Temperature_Sensor', 'OfficeA', 25.37), ('2026-07-19 13:53:49', 'DEV007', 'Temperature_Sensor', 'Lab2', 25.14), ('2026-07-19 13:54:49', 'DEV008', 'Humidity_Sensor', 'OfficeA', 42.4), ('2026-07-19 13:55:49', 'DEV009', 'Pressure_Sensor', 'OfficeA', 1012.35), ('2026-07-19 13:56:49', 'DEV010', 'Temperature_Sensor', 'Lab1', 29.68), ('2026-07-19 13:57:49', 'DEV011', 'Pressure_Sensor', 'Lab1', 986.78), ('2026-07-19 13:58:49', 'DEV012', 'Light_Sensor', 'Lab1', 519.44), ('2026-07-19 13:59:49', 'DEV013', 'Temperature_Sensor', 'Lab2', 18.66), ('2026-07-19 14:00:49', 'DEV014', 'Pressure_Sensor', 'Warehouse', 1029.52), ('2026-07-19 14:01:49', 'DEV015', 'Humidity_Sensor', 'OfficeA', 57.53), ('2026-07-19 14:02:49', 'DEV016', 'Pressure_Sensor', 'OfficeB', 1028.81), ('2026-07-19 14:03:49', 'DEV017', 'Temperature_Sensor', 'OfficeA', 21.65), ('2026-07-19 14:04:49', 'DEV018', 'Humidity_Sensor', 'Lab1', 36.61), ('2026-07-19 14:05:49', 'DEV019', 'Temperature_Sensor', 'Warehouse', 26.86), ('2026-07-19 14:06:49', 'DEV020', 'Light_Sensor', 'Lab1', 340.26), ('2026-07-19 14:07:49', 'DEV021', 'Light_Sensor', 'OfficeA', 384.62), ('2026-07-19 14:08:49', 'DEV022', 'Temperature_Sensor', 'Lab1', 19.01), ('2026-07-19 14:09:49', 'DEV023', 'Humidity_Sensor', 'Lab1', 71.37), ('2026-07-19 14:10:49', 'DEV024', 'Temperature_Sensor', 'OfficeA', 28.44), ('2026-07-19 14:11:49', 'DEV025', 'Temperature_Sensor', 'OfficeA', 25.86), ('2026-07-19 14:12:49', 'DEV026', 'Temperature_Sensor', 'Warehouse', 18.8), ('2026-07-19 14:13:49', 'DEV027', 'Light_Sensor', 'Lab1', 633.12), ('2026-07-19 14:14:49', 'DEV028', 'Humidity_Sensor', 'Lab1', 40.04), ('2026-07-19 14:15:49', 'DEV029', 'Temperature_Sensor', 'OfficeA', 22.29), ('2026-07-19 14:16:49', 'DEV030', 'Light_Sensor', 'OfficeB', 357.61), ('2026-07-19 14:17:49', 'DEV031', 'Humidity_Sensor', 'OfficeB', 48.02), ('2026-07-19 14:18:49', 'DEV032', 'Pressure_Sensor', 'Lab1', 1003.48), ('2026-07-19 14:19:49', 'DEV033', 'Pressure_Sensor', 'OfficeA', 988.97), ('2026-07-19 14:20:49', 'DEV034', 'Pressure_Sensor', 'Lab1', 1019.19), ('2026-07-19 14:21:49', 'DEV035', 'Temperature_Sensor', 'Warehouse', 28.73), ('2026-07-19 14:22:49', 'DEV036', 'Light_Sensor', 'Warehouse', 348.82), ('2026-07-19 14:23:49', 'DEV037', 'Pressure_Sensor', 'Lab2', 1008.53), ('2026-07-19 14:24:49', 'DEV038', 'Humidity_Sensor', 'Warehouse', 53.16), ('2026-07-19 14:25:49', 'DEV039', 'Pressure_Sensor', 'OfficeB', 1018.97), ('2026-07-19 14:26:49', 'DEV040', 'Humidity_Sensor', 'OfficeA', 78.18), ('2026-07-19 14:27:49', 'DEV041', 'Pressure_Sensor', 'OfficeB', 984.51), ('2026-07-19 14:28:49', 'DEV042', 'Light_Sensor', 'Lab2', 663.53), ('2026-07-19 14:29:49', 'DEV043', 'Light_Sensor', 'Lab2', 465.66), ('2026-07-19 14:30:49', 'DEV044', 'Humidity_Sensor', 'Lab2', 54.2), ('2026-07-19 14:31:49', 'DEV045', 'Pressure_Sensor', 'Warehouse', 996.82), ('2026-07-19 14:32:49', 'DEV046', 'Temperature_Sensor', 'OfficeB', 18.49), ('2026-07-19 14:33:49', 'DEV047', 'Light_Sensor', 'Lab1', 408.28), ('2026-07-19 14:34:49', 'DEV048', 'Humidity_Sensor', 'Lab1', 67.66), ('2026-07-19 14:35:49', 'DEV049', 'Temperature_Sensor', 'OfficeA', 29.43), ('2026-07-19 14:36:49', 'DEV050', 'Temperature_Sensor', 'OfficeB', 18.98), ('2026-07-19 14:37:49', 'DEV051', 'Light_Sensor', 'OfficeB', 768.52), ('2026-07-19 14:38:49', 'DEV052', 'Temperature_Sensor', 'OfficeB', 22.1), ('2026-07-19 14:39:49', 'DEV053', 'Temperature_Sensor', 'OfficeB', 25.58), ('2026-07-19 14:40:49', 'DEV054', 'Light_Sensor', 'Lab2', 630.76), ('2026-07-19 14:41:49', 'DEV055', 'Humidity_Sensor', 'Lab2', 35.83), ('2026-07-19 14:42:49', 'DEV056', 'Humidity_Sensor', ...

# %%
# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })
print(temperature_readings)
# Out:
# [{'timestamp': '2026-07-19 13:51:49', 'device_id': 'DEV005', 'location': 'OfficeB', 'temperature_celsius': 23.82}, {'timestamp': '2026-07-19 13:52:49', 'device_id': 'DEV006', 'location': 'OfficeA', 'temperature_celsius': 25.37}, {'timestamp': '2026-07-19 13:53:49', 'device_id': 'DEV007', 'location': 'Lab2', 'temperature_celsius': 25.14}, {'timestamp': '2026-07-19 13:56:49', 'device_id': 'DEV010', 'location': 'Lab1', 'temperature_celsius': 29.68}, {'timestamp': '2026-07-19 13:59:49', 'device_id': 'DEV013', 'location': 'Lab2', 'temperature_celsius': 18.66}, {'timestamp': '2026-07-19 14:03:49', 'device_id': 'DEV017', 'location': 'OfficeA', 'temperature_celsius': 21.65}, {'timestamp': '2026-07-19 14:05:49', 'device_id': 'DEV019', 'location': 'Warehouse', 'temperature_celsius': 26.86}, {'timestamp': '2026-07-19 14:08:49', 'device_id': 'DEV022', 'location': 'Lab1', 'temperature_celsius': 19.01}, {'timestamp': '2026-07-19 14:10:49', 'device_id': 'DEV024', 'location': 'OfficeA', 'temperature_celsius': 28.44}, {'timestamp': '2026-07-19 14:11:49', 'device_id': 'DEV025', 'location': 'OfficeA', 'temperature_celsius': 25.86}, {'timestamp': '2026-07-19 14:12:49', 'device_id': 'DEV026', 'location': 'Warehouse', 'temperature_celsius': 18.8}, {'timestamp': '2026-07-19 14:15:49', 'device_id': 'DEV029', 'location': 'OfficeA', 'temperature_celsius': 22.29}, {'timestamp': '2026-07-19 14:21:49', 'device_id': 'DEV035', 'location': 'Warehouse', 'temperature_celsius': 28.73}, {'timestamp': '2026-07-19 14:32:49', 'device_id': 'DEV046', 'location': 'OfficeB', 'temperature_celsius': 18.49}, {'timestamp': '2026-07-19 14:35:49', 'device_id': 'DEV049', 'location': 'OfficeA', 'temperature_celsius': 29.43}, {'timestamp': '2026-07-19 14:36:49', 'device_id': 'DEV050', 'location': 'OfficeB', 'temperature_celsius': 18.98}, {'timestamp': '2026-07-19 14:38:49', 'device_id': 'DEV052', 'location': 'OfficeB', 'temperature_celsius': 22.1}, {'timestamp': '2026-07-19 14:39:49', 'device_id': 'DEV053', 'location': 'OfficeB', 'temperature_celsius': 25.58}, {'timestamp': '2026-07-19 14:48:49', 'device_id': 'DEV062', 'location': 'OfficeB', 'temperature_celsius': 18.8}, {'timestamp': '2026-07-19 14:49:49', 'device_id': 'DEV063', 'location': 'Lab1', 'temperature_celsius': 19.0}, {'timestamp': '2026-07-19 14:57:49', 'device_id': 'DEV071', 'location': 'Lab1', 'temperature_celsius': 29.17}, {'timestamp': '2026-07-19 15:01:49', 'device_id': 'DEV075', 'location': 'Lab1', 'temperature_celsius': 28.3}, {'timestamp': '2026-07-19 15:08:49', 'device_id': 'DEV082', 'location': 'OfficeB', 'temperature_celsius': 28.83}, {'timestamp': '2026-07-19 15:12:49', 'device_id': 'DEV086', 'location': 'OfficeA', 'temperature_celsius': 25.64}, {'timestamp': '2026-07-19 15:16:49', 'device_id': 'DEV090', 'location': 'Lab1', 'temperature_celsius': 21.25}, {'timestamp': '2026-07-19 15:20:49', 'device_id': 'DEV094', 'location': 'OfficeB', 'temperature_celsius': 24.37}]

# %%
# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.

# Your code for Task 1.3 here:
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])
print(unique_locations)
# Out:
# {'Lab2', 'Warehouse', 'OfficeB', 'Lab1', 'OfficeA'}

# %%
# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.

# Your code for Task 1.4 here:
device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]

    minimum, maximum = device_stats[device]

    if value < minimum:
        minimum = value

    if value > maximum:
        maximum = value

    device_stats[device] = (minimum, maximum)
print(device_stats)
print(device_type)
# Out:
# {'Temperature_Sensor': (18.49, 29.68), 'Humidity_Sensor': (35.39, 79.78), 'Pressure_Sensor': (982.09, 1029.68), 'Light_Sensor': (122.83, 855.31)}
# Humidity_Sensor

# %%
# 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.

# Your code for Task 1.5.1 here:
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]
print(sliced_readings_1)
print(sliced_readings_2)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# [('2026-07-19 13:56:49', 'DEV010', 'Temperature_Sensor', 'Lab1', 29.68), ('2026-07-19 13:57:49', 'DEV011', 'Pressure_Sensor', 'Lab1', 986.78), ('2026-07-19 13:58:49', 'DEV012', 'Light_Sensor', 'Lab1', 519.44), ('2026-07-19 13:59:49', 'DEV013', 'Temperature_Sensor', 'Lab2', 18.66), ('2026-07-19 14:00:49', 'DEV014', 'Pressure_Sensor', 'Warehouse', 1029.52), ('2026-07-19 14:01:49', 'DEV015', 'Humidity_Sensor', 'OfficeA', 57.53), ('2026-07-19 14:02:49', 'DEV016', 'Pressure_Sensor', 'OfficeB', 1028.81), ('2026-07-19 14:03:49', 'DEV017', 'Temperature_Sensor', 'OfficeA', 21.65), ('2026-07-19 14:04:49', 'DEV018', 'Humidity_Sensor', 'Lab1', 36.61), ('2026-07-19 14:05:49', 'DEV019', 'Temperature_Sensor', 'Warehouse', 26.86), ('2026-07-19 14:06:49', 'DEV020', 'Light_Sensor', 'Lab1', 340.26)]
# [('2026-07-19 13:47:49', 'DEV001', 'Light_Sensor', 'Lab1', 415.1), ('2026-07-19 13:52:49', 'DEV006', 'Temperature_Sensor', 'OfficeA', 25.37), ('2026-07-19 13:57:49', 'DEV011', 'Pressure_Sensor', 'Lab1', 986.78), ('2026-07-19 14:02:49', 'DEV016', 'Pressure_Sensor', 'OfficeB', 1028.81), ('2026-07-19 14:07:49', 'DEV021', 'Light_Sensor', 'OfficeA', 384.62), ('2026-07-19 14:12:49', 'DEV026', 'Temperature_Sensor', 'Warehouse', 18.8), ('2026-07-19 14:17:49', 'DEV031', 'Humidity_Sensor', 'OfficeB', 48.02), ('2026-07-19 14:22:49', 'DEV036', 'Light_Sensor', 'Warehouse', 348.82), ('2026-07-19 14:27:49', 'DEV041', 'Pressure_Sensor', 'OfficeB', 984.51), ('2026-07-19 14:32:49', 'DEV046', 'Temperature_Sensor', 'OfficeB', 18.49), ('2026-07-19 14:37:49', 'DEV051', 'Light_Sensor', 'OfficeB', 768.52), ('2026-07-19 14:42:49', 'DEV056', 'Humidity_Sensor', 'Warehouse', 75.27), ('2026-07-19 14:47:49', 'DEV061', 'Pressure_Sensor', 'Lab2', 982.47), ('2026-07-19 14:52:49', 'DEV066', 'Light_Sensor', 'Lab2', 783.57), ('2026-07-19 14:57:49', 'DEV071', 'Temperature_Sensor', 'Lab1', 29.17), ('2026-07-19 15:02:49', 'DEV076', 'Humidity_Sensor', 'OfficeB', 46.26), ('2026-07-19 15:07:49', 'DEV081', 'Pressure_Sensor', 'OfficeB', 996.55), ('2026-07-19 15:12:49', 'DEV086', 'Temperature_Sensor', 'OfficeA', 25.64), ('2026-07-19 15:17:49', 'DEV091', 'Pressure_Sensor', 'Lab2', 1016.09), ('2026-07-19 15:22:49', 'DEV096', 'Pressure_Sensor', 'Lab2', 1011.98)]

# %%
# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:
substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]
print(substring_1)
print(substring_2)
# Out:
# Programming
# nohtyP

# %%
# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.

# Your code for Task 1.5.3 here:
fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]
print(fifth_reading_device_type)
print(device_type_suffix)
# Out:
# Temperature_Sensor
# Sensor

# %%
# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:
def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result
location = "Lab1"
lab_readings = get_readings_by_location(raw_sensor_data, location)

print(f"Readings from {location}:")
for reading in lab_readings:
    print(reading)
# Out:
# --- Task 2: Function Definitions and Usage ---
# Readings from Lab1:
# ('2026-07-19 13:47:49', 'DEV001', 'Light_Sensor', 'Lab1', 415.1)
# ('2026-07-19 13:48:49', 'DEV002', 'Light_Sensor', 'Lab1', 629.24)
# ('2026-07-19 13:50:49', 'DEV004', 'Pressure_Sensor', 'Lab1', 1008.92)
# ('2026-07-19 13:56:49', 'DEV010', 'Temperature_Sensor', 'Lab1', 29.68)
# ('2026-07-19 13:57:49', 'DEV011', 'Pressure_Sensor', 'Lab1', 986.78)
# ('2026-07-19 13:58:49', 'DEV012', 'Light_Sensor', 'Lab1', 519.44)
# ('2026-07-19 14:04:49', 'DEV018', 'Humidity_Sensor', 'Lab1', 36.61)
# ('2026-07-19 14:06:49', 'DEV020', 'Light_Sensor', 'Lab1', 340.26)
# ('2026-07-19 14:08:49', 'DEV022', 'Temperature_Sensor', 'Lab1', 19.01)
# ('2026-07-19 14:09:49', 'DEV023', 'Humidity_Sensor', 'Lab1', 71.37)
# ('2026-07-19 14:13:49', 'DEV027', 'Light_Sensor', 'Lab1', 633.12)
# ('2026-07-19 14:14:49', 'DEV028', 'Humidity_Sensor', 'Lab1', 40.04)
# ('2026-07-19 14:18:49', 'DEV032', 'Pressure_Sensor', 'Lab1', 1003.48)
# ('2026-07-19 14:20:49', 'DEV034', 'Pressure_Sensor', 'Lab1', 1019.19)
# ('2026-07-19 14:33:49', 'DEV047', 'Light_Sensor', 'Lab1', 408.28)
# ('2026-07-19 14:34:49', 'DEV048', 'Humidity_Sensor', 'Lab1', 67.66)
# ('2026-07-19 14:45:49', 'DEV059', 'Light_Sensor', 'Lab1', 619.33)
# ('2026-07-19 14:49:49', 'DEV063', 'Temperature_Sensor', 'Lab1', 19.0)
# ('2026-07-19 14:53:49', 'DEV067', 'Pressure_Sensor', 'Lab1', 997.33)
# ('2026-07-19 14:54:49', 'DEV068', 'Light_Sensor', 'Lab1', 729.62)
# ('2026-07-19 14:55:49', 'DEV069', 'Pressure_Sensor', 'Lab1', 1023.63)
# ('2026-07-19 14:56:49', 'DEV070', 'Light_Sensor', 'Lab1', 122.83)
# ('2026-07-19 14:57:49', 'DEV071', 'Temperature_Sensor', 'Lab1', 29.17)
# ('2026-07-19 15:01:49', 'DEV075', 'Temperature_Sensor', 'Lab1', 28.3)
# ('2026-07-19 15:16:49', 'DEV090', 'Temperature_Sensor', 'Lab1', 21.25)
# ('2026-07-19 15:23:49', 'DEV097', 'Pressure_Sensor', 'Lab1', 996.86)

# %%
# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:
def calculate_average_temperature(temp_data_list):

    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for item in temp_data_list:
        total += item["temperature_celsius"]

    return total / len(temp_data_list)
average_temp = calculate_average_temperature(temperature_readings)
print("Average Temperature:", round(average_temp, 2), "°C")
# Out:
# Average Temperature: 24.01 °C

# %%
# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

# Your code for Task 2.3 here:
def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"
if len(temperature_readings) > 0:
    report = generate_report_line(temperature_readings[0])
    print(report)
else:
    print("No temperature readings available.")
# Out:
# [2026-07-19 13:51:49] Device DEV005 at OfficeB: 23.82°C

# %%
# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' already exists.

# %%
# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 1 hours, 39 minutes.

# %%
# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:
random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("Random Values:", random_values)
# Out:
# Random Values: [160, 145, 149, 123, 114]
